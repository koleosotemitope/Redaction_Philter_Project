# %%
import pteredactyl

# %%
pteredactyl.analyse('asjdklajsdl')
# Out:
# Device set to use cuda:0
# [type: ID, start: 0, end: 9, score: 0.4699999988079071,
#  type: PERSON, start: 9, end: 11, score: 0.7400000095367432]
